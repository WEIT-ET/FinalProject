# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv("test.csv")
train_df
# Out:
#                   ID     User-ID      Book-ID  Book-Rating   Age  \
# 0       TRAIN_000000  USER_00000  BOOK_044368            8  23.0
# 1       TRAIN_000001  USER_00000  BOOK_081205            8  23.0
# 2       TRAIN_000002  USER_00000  BOOK_086781            0  23.0
# 3       TRAIN_000003  USER_00000  BOOK_098622            0  23.0
# 4       TRAIN_000004  USER_00000  BOOK_180810            8  23.0
# ...              ...         ...          ...          ...   ...
# 664422  TRAIN_664422  USER_69514  BOOK_104147            0  35.0
# 664423  TRAIN_664423  USER_69514  BOOK_112969            0  35.0
# 664424  TRAIN_664424  USER_69514  BOOK_115771            0  35.0
# 664425  TRAIN_664425  USER_69514  BOOK_116028            0  35.0
# 664426  TRAIN_664426  USER_69514  BOOK_118177            0  35.0
#
#                                 Location  \
# 0       sackville, new brunswick, canada
# 1       sackville, new brunswick, canada
# 2       sackville, new brunswick, canada
# 3       sackville, new brunswick, canada
# 4       sackville, new brunswick, canada
# ...                                  ...
# 664422           auxvasse, missouri, usa
# 664423           auxvasse, missouri, usa
# 664424           auxvasse, missouri, usa
# 664425           auxvasse, missouri, usa
# 664426           auxvasse, missouri, usa
#
#                                           Book-Title          Book-Author  \
# 0                                         Road Taken           Rona Jaffe
# 1                  Macbeth (New Penguin Shakespeare)  William Shakespeare
# 2                 Waverley (Penguin English Library)         Walter Scott
# 3                            Mother Earth Father Sky         Sue Harrison
# 4                                  She Who Remembers     Linda Lay Shuler
# ...                                              ...                  ...
# 664422                             Wuthering Heights         EMILY BRONTE
# 664423  Magic Crystal (Teenage Mutant Ninja Turtles)        Kevin Eastman
# 664424                              You Belong To Me   Mary Higgins Clark
# 664425                     The Bonesetter's Daughter              Amy Tan
# 664426                                HOLLYWOOD KIDS                  NaN
#
#         Year-Of-Publication                Publisher
# 0                    2001.0                     Mira
# 1                    1981.0            Penguin Books
# 2                    1981.0            Penguin Books
# 3                    1991.0                     Avon
# 4                    1989.0              Signet Book
# ...                     ...                      ...
# 664422               1983.0                   Bantam
# 664423               1990.0              Happy House
# 664424               1999.0             Pocket Books
# 664425               2001.0  Putnam Publishing Group
# 664426                  NaN                      NaN
#
# [664427 rows x 10 columns]

# %%
train_df.shape
# Out:
# (664427, 10)

# %%
train_df.isnull().sum()
# Out:
# ID                     0
# User-ID                0
# Book-ID                0
# Book-Rating            0
# Age                    0
# Location               0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664427 entries, 0 to 664426
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   664427 non-null  object
#  1   User-ID              664427 non-null  object
#  2   Book-ID              664427 non-null  object
#  3   Book-Rating          664427 non-null  int64
#  4   Age                  664427 non-null  float64
#  5   Location             664427 non-null  object
#  6   Book-Title           664427 non-null  object
#  7   Book-Author          664426 non-null  object
#  8   Year-Of-Publication  664426 non-null  float64
#  9   Publisher            664426 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 50.7+ MB

# %%
train_df.describe()
# Out:
#          Book-Rating            Age  Year-Of-Publication
# count  664427.000000  664427.000000        664426.000000
# mean        2.847515      36.940636          1969.225190
# std         3.855610      11.961557           226.730574
# min         0.000000       0.000000            -1.000000
# 25%         0.000000      31.000000          1991.000000
# 50%         0.000000      35.000000          1997.000000
# 75%         7.000000      42.000000          2001.000000
# max        10.000000     244.000000          2021.000000

# %%
train_df.isnull()
# Out:
#            ID  User-ID  Book-ID  Book-Rating    Age  Location  Book-Title  \
# 0       False    False    False        False  False     False       False
# 1       False    False    False        False  False     False       False
# 2       False    False    False        False  False     False       False
# 3       False    False    False        False  False     False       False
# 4       False    False    False        False  False     False       False
# ...       ...      ...      ...          ...    ...       ...         ...
# 664422  False    False    False        False  False     False       False
# 664423  False    False    False        False  False     False       False
# 664424  False    False    False        False  False     False       False
# 664425  False    False    False        False  False     False       False
# 664426  False    False    False        False  False     False       False
#
#         Book-Author  Year-Of-Publication  Publisher
# 0             False                False      False
# 1             False                False      False
# 2             False                False      False
# 3             False                False      False
# 4             False                False      False
# ...             ...                  ...        ...
# 664422        False                False      False
# 664423        False                False      False
# 664424        False                False      False
# 664425        False                False      False
# 664426         True                 True       True
#
# [664427 rows x 10 columns]

# %%
train_df['Book-Rating'].plot.hist(bins=range(0,10,1),color='y', edgecolor='k', title = 'Book-Rating distribution(Train)')
# Out:
# <Axes: title={'center': 'Book-Rating distribution(Train)'}, ylabel='Frequency'>

# %%
train_df['Age'].plot.hist(bins=range(0,100,10),color='c', edgecolor='k', title = 'Age distribution(Train)')
# Out:
# <Axes: title={'center': 'Age distribution(Train)'}, ylabel='Frequency'>

# %%
train_df['Year-Of-Publication'].plot.hist(bins=range(1950,2020,10),color='g', edgecolor='k', title = 'Year of publication distribution(Train)')
# Out:
# <Axes: title={'center': 'Year of publication distribution(Train)'}, ylabel='Frequency'>

# %%
plt.subplot(2, 2, 1)
et0= train_df.groupby('User-ID').count()
et0['ID'].plot.hist(bins=range(1,20,1),color='yellow', edgecolor='k',title = 'Number of User-ID(Train)')

plt.subplot(2, 2, 3)
et0= train_df.groupby('Book-ID').count()
et0['ID'].plot.hist(bins=range(1,20,1),color='pink', edgecolor='k',title = 'Number of Book-ID(Train)')


plt.tight_layout(
    h_pad=3, # 세로 간격 조절
    w_pad=4) # 가로 간격 조걸

# %%
# 작가별 count
et = test_df.groupby('Book-Author').count()
et['name']= et.index
et = et[['name','ID']]
et = et.drop_duplicates(['name'])
# Top 10 추출
et_top10 = et.sort_values(by="ID", ascending=False).head(10)

plt.subplot(2, 1, 1)
sns.barplot(data=et_top10, y="name", x="ID", orient='h', edgecolor='k',color='dodgerblue')
plt.title('Top 10 Author(Train)')


# Book-Title별 count
et = test_df.groupby('Book-Title').count()
et['name']= et.index
et = et[['name','ID']]
et = et.drop_duplicates(['name'])
# Top 10 추출
et_top10 = et.sort_values(by="ID", ascending=False).head(10)

plt.subplot(2, 1, 2)
sns.barplot(data=et_top10, y="name", x="ID", orient='h', edgecolor='k',color='dodgerblue')
plt.title('Top 10 Book-title(Train)')

plt.tight_layout(
    h_pad=2, # 세로 간격 조절
    w_pad=0) # 가로 간격 조걸
